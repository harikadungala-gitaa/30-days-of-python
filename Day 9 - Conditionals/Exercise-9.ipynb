# %% [markdown]
# LEVEL-1

# %%
# Day 9: 30 Days of Python - Conditionals Exercises

# -------------------------------
# 🧩 Exercises: Level 1
# -------------------------------

# 1️⃣ Check driving age
age = int(input("Enter your age: "))

if age >= 18:
    print("You are old enough to learn to drive.")
else:
    remaining_years = 18 - age
    print(f"You need {remaining_years} more years to learn to drive.")
# Out:
# You are old enough to learn to drive.

# %%
# 2️⃣ Compare ages
my_age = 25  # you can change this to your actual age
your_age = int(input("Enter your age: "))

if your_age > my_age:
    diff = your_age - my_age
    if diff == 1:
        print("You are 1 year older than me.")
    else:
        print(f"You are {diff} years older than me.")
elif your_age < my_age:
    diff = my_age - your_age
    if diff == 1:
        print("I am 1 year older than you.")
    else:
        print(f"I am {diff} years older than you.")
else:
    print("We are the same age!")
# Out:
# I am 5 years older than you.

# %%
# 3️⃣ Compare two numbers
a = int(input("Enter number one: "))
b = int(input("Enter number two: "))

if a > b:
    print(f"{a} is greater than {b}")
elif a < b:
    print(f"{a} is smaller than {b}")
else:
    print(f"{a} is equal to {b}")
# Out:
# 2 is smaller than 3

# %% [markdown]
# LEVEL-2

# %%
# 4️ Grade system
score = int(input("Enter your score: "))

if 80 <= score <= 100:
    grade = "A"
elif 70 <= score <= 79:
    grade = "B"
elif 60 <= score <= 69:
    grade = "C"
elif 50 <= score <= 59:
    grade = "D"
elif 0 <= score < 50:
    grade = "F"
else:
    grade = "Invalid score"

print(f"Your grade is {grade}")
# Out:
# Your grade is B

# %%
# 5️⃣ Season checker
month = input("Enter the month: ").capitalize()

if month in ["September", "October", "November"]:
    season = "Autumn"
elif month in ["December", "January", "February"]:
    season = "Winter"
elif month in ["March", "April", "May"]:
    season = "Spring"
elif month in ["June", "July", "August"]:
    season = "Summer"
else:
    season = "Invalid month"

print(f"The season is {season}.")
# Out:
# The season is Invalid month.

# %%
# 6️⃣ Fruit check
fruits = ['banana', 'orange', 'mango', 'lemon']
new_fruit = input("Enter a fruit name: ").lower()

if new_fruit in fruits:
    print("That fruit already exists in the list.")
else:
    fruits.append(new_fruit)
    print("Fruit added! Updated list:", fruits)
# Out:
# Fruit added! Updated list: ['banana', 'orange', 'mango', 'lemon', 'apple']

# %% [markdown]
# LEVEL-3

# %%
person = {
    'first_name': 'Asabeneh',
    'last_name': 'Yetayeh',
    'age': 250,
    'country': 'Finland',
    'is_married': True,
    'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python'],
    'address': {
        'street': 'Space street',
        'zipcode': '02210'
    }
}

# %%
# 7️⃣ Check if person has skills key and print middle skill
if 'skills' in person:
    skills = person['skills']
    middle_index = len(skills) // 2
    print("Middle skill:", skills[middle_index])
# Out:
# Middle skill: Node

# %%
# 8️⃣ Check if person has Python skill
if 'skills' in person:
    has_python = 'Python' in person['skills']
    print("Has Python skill?", has_python)
# Out:
# Has Python skill? True

# %%
# 9️⃣ Developer type detection
skills = person.get('skills', [])
if set(skills) == {'JavaScript', 'React'}:
    print("He is a front end developer")
elif {'Node', 'Python', 'MongoDB'}.issubset(skills):
    print("He is a backend developer")
elif {'React', 'Node', 'MongoDB'}.issubset(skills):
    print("He is a fullstack developer")
else:
    print("Unknown title")
# Out:
# He is a backend developer

# %%
# 🔟 Check if married and living in Finland
if person.get('is_married') and person.get('country') == 'Finland':
    print(f"{person['first_name']} {person['last_name']} lives in {person['country']}. He is married.")
# Out:
# Asabeneh Yetayeh lives in Finland. He is married.
